# %% [markdown]
# ### **Exemplo - Exercício 8**

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### **Leitura do arquivo csv**

# %%
data_path = os.path.join(os.getcwd(),'data_exemplo.csv')
df = pd.read_csv(data_path)

# %% [markdown]
# #### **Exibindo as primeiras linhas**

# %%
display(df.head()) # Exibindo as cinco primeiras linhas (default)
# Out:
#    id  marca  ram_gb  armazenamento_gb  nucleos_cpu  vram_gpu_gb  \
# 0   1  Apple       8               256            8            4
# 1   2   Acer       8              2048            4            0
# 2   3   Dell       8               512           16            8
# 3   4     HP      16              2048            8            6
# 4   5     HP       8               256           12            0
#
#    clock_cpu_ghz  preco_rs
# 0           2.71   4860.08
# 1           2.30   5267.20
# 2           2.71   7078.96
# 3           2.50   8161.93
# 4           3.15   4468.57

# %%
display(df.head(3)) # Exibindo as três primeiras linhas
# Out:
#    id  marca  ram_gb  armazenamento_gb  nucleos_cpu  vram_gpu_gb  \
# 0   1  Apple       8               256            8            4
# 1   2   Acer       8              2048            4            0
# 2   3   Dell       8               512           16            8
#
#    clock_cpu_ghz  preco_rs
# 0           2.71   4860.08
# 1           2.30   5267.20
# 2           2.71   7078.96

# %%
display(df.head(10)) # Exibindo as dez primeiras linhas
# Out:
#    id   marca  ram_gb  armazenamento_gb  nucleos_cpu  vram_gpu_gb  \
# 0   1   Apple       8               256            8            4
# 1   2    Acer       8              2048            4            0
# 2   3    Dell       8               512           16            8
# 3   4      HP      16              2048            8            6
# 4   5      HP       8               256           12            0
# 5   6    Acer       8              2048           16            0
# 6   7  Lenovo      32              1024           16            4
# 7   8      HP      32               256            6            0
# 8   9   Apple      16              1024            8            4
# 9  10      HP       8               512           16           16
#
#    clock_cpu_ghz  preco_rs
# 0           2.71   4860.08
# 1           2.30   5267.20
# 2           2.71   7078.96
# 3           2.50   8161.93
# 4           3.15   4468.57
# 5           5.11   7435.72
# 6           4.25   8641.29
# ...

# %% [markdown]
# #### **Exibindo as ùltimas linhas**

# %%
display(df.tail()) # Exibindo as cinco últimas linhas (default)
# Out:
#     id   marca  ram_gb  armazenamento_gb  nucleos_cpu  vram_gpu_gb  \
# 25  26    Dell      16               512            4            0
# 26  27  Lenovo       8              1024            4           12
# 27  28    Dell      16              2048            6            8
# 28  29   Apple      64              1024           12            8
# 29  30  Lenovo       8               256           12           16
#
#     clock_cpu_ghz  preco_rs
# 25           4.27   4156.72
# 26           2.76   6746.19
# 27           4.58   8009.85
# 28           3.49  11735.25
# 29           3.09   7973.20

# %%
display(df.tail(10)) # Exibindo as dez últimas linhas
# Out:
#     id   marca  ram_gb  armazenamento_gb  nucleos_cpu  vram_gpu_gb  \
# 20  21    Dell      32               512            4            4
# 21  22    Acer      64               256           16            4
# 22  23    Acer      16              1024           16           12
# 23  24    Acer      16              1024           12           16
# 24  25    Acer      64               256            6            4
# 25  26    Dell      16               512            4            0
# 26  27  Lenovo       8              1024            4           12
# 27  28    Dell      16              2048            6            8
# 28  29   Apple      64              1024           12            8
# 29  30  Lenovo       8               256           12           16
#
#     clock_cpu_ghz  preco_rs
# 20           4.81   6823.57
# 21           2.41  10353.37
# 22           3.35   8970.88
# 23           4.08   9379.66
# 24           2.20   8559.82
# 25           4.27   4156.72
# ...

# %%
display(df.tail(2)) # Exibindo as 2 últimas linhas
# Out:
#     id   marca  ram_gb  armazenamento_gb  nucleos_cpu  vram_gpu_gb  \
# 28  29   Apple      64              1024           12            8
# 29  30  Lenovo       8               256           12           16
#
#     clock_cpu_ghz  preco_rs
# 28           3.49  11735.25
# 29           3.09   7973.20
