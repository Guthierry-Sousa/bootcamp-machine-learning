# %% [markdown]
# ### **Exercício 5**

# %% [markdown]
# #### **5.** Crie uma função que receba uma lista de tuplas, cada uma contendo o nome e a idade de uma pessoa, e retorne a lista ordenada pelo nome das pessoas em ordem alfabética.

# %%
def ordenacao_alfabetica(lista: list) -> list:

    lista_ordenada = sorted(lista, key = lambda x: x[0].lower())

    return lista_ordenada

# %%
lista = [
    ("Guthierry", 19),
    ("Elis", 19),
    ("Elen", 19),
    ("Yanni", 4),
    ("Neymar", 30),
    ("Ana", 60)
]

print(lista)
# Out:
# [('Guthierry', 19), ('Elis', 19), ('Elen', 19), ('Yanni', 4), ('Neymar', 30), ('Ana', 60)]

# %%
lista_ordenada_por_nome = ordenacao_alfabetica(lista=lista)

print(lista_ordenada_por_nome)
# Out:
# [('Ana', 60), ('Elen', 19), ('Elis', 19), ('Guthierry', 19), ('Neymar', 30), ('Yanni', 4)]
