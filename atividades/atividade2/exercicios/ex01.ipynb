# %% [markdown]
# ### **Exercício 01**

# %%
import random as rd

# %% [markdown]
# #### **1.** Escreva uma função que receba uma lista de números e retorne outra lista com os números ímpares.

# %%
def filtro_impares(lista: list) -> list:
    """A função recebe uma lista e retorna outra lista apenas com os números ímpares."""
    lista_impares = [x for x in lista if x%2 != 0]

    return lista_impares

# %%
lista = [rd.randint(1, 100) for _ in range(10)]
print(f"Lista Original: {lista}")
# Out:
# Lista Original: [63, 76, 89, 89, 58, 53, 33, 37, 84, 19]

# %%
lista_impares = filtro_impares(lista=lista)
print(f"Lista filtrada (apenas com números ímpares): {lista_impares}")
# Out:
# Lista filtrada (apenas com números ímpares): [63, 89, 89, 53, 33, 37, 19]
