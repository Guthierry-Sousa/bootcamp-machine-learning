# %% [markdown]
# ### **Exercício 4**

# %%
import random as rd

# %% [markdown]
# #### **4.** Dada uma lista de números inteiros, escreva uma função para encontrar o segundo maior valor na lista.

# %%
def segundo_maior_valor(lista: list) -> int:
    lista.sort()

    return lista[-2]

# %%
lista = [rd.randint(1, 100) for _ in range(10)]
print(f"Lista Original: {lista}")
# Out:
# Lista Original: [37, 87, 9, 47, 28, 72, 82, 24, 68, 30]

# %%
print(f"Segundo maior valor = {segundo_maior_valor(lista=lista)}")
# Out:
# Segundo maior valor = 82
